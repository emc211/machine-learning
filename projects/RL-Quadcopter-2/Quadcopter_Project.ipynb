# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([5., 3., 11., 4., 3., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 0.17222171 36.805962    0.          3.82995576  3.06863043  0.        ]
# [ -3.06115014  29.57191774 -14.55586215]
# [-0.01202479  0.00972104  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale))
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -4.005 (best =  -4.005), noise_scale = 0.05
# Episode =    2, score =  -3.765 (best =  -3.765), noise_scale = 0.025
# Episode =    3, score =  -3.673 (best =  -3.673), noise_scale = 0.0125
# Episode =    4, score =  -3.867 (best =  -3.673), noise_scale = 0.025
# Episode =    5, score =  -3.541 (best =  -3.541), noise_scale = 0.0125
# Episode =    6, score =  -3.861 (best =  -3.541), noise_scale = 0.025
# Episode =    7, score =  -3.605 (best =  -3.541), noise_scale = 0.05
# Episode =    8, score =  -4.370 (best =  -3.541), noise_scale = 0.1
# Episode =    9, score =  -3.783 (best =  -3.541), noise_scale = 0.2
# Episode =   10, score =  -4.387 (best =  -3.541), noise_scale = 0.4
# Episode =   11, score =  -4.340 (best =  -3.541), noise_scale = 0.8
# Episode =   12, score =  -4.074 (best =  -3.541), noise_scale = 1.6
# Episode =   13, score =  -5.550 (best =  -3.541), noise_scale = 3.2
# Episode =   14, score =  -4.362 (best =  -3.541), noise_scale = 3.2
# Episode =   15, score =  -5.082 (best =  -3.541), noise_scale = 3.2
# Episode =   16, score =  -3.547 (best =  -3.541), noise_scale = 3.2
# Episode =   17, score =  -3.891 (best =  -3.541), noise_scale = 3.2
# Episode =   18, score =  -3.231 (best =  -3.231), noise_scale = 1.6
# Episode =   19, score =  -3.154 (best =  -3.154), noise_scale = 0.8
# Episode =   20, score =  -3.148 (best =  -3.148), noise_scale = 0.4
# Episode =   21, score =  -3.426 (best =  -3.148), noise_scale = 0.8
# Episode =   22, score =  -3.174 (best =  -3.148), noise_scale = 1.6
# Episode =   23, score =  -3.195 (best =  -3.148), noise_scale = 3.2
# Episode =   24, score =  -3.287 (best =  -3.148), noise_scale = 3.2
# Episode =   25, score =  -3.160 (best =  -3.148), noise_scale = 3.2
# Episode =   26, score =  -3.378 (best =  -3.148), noise_scale = 3.2
# Episode =   27, score =  -3.187 (best =  -3.148), noise_scale = 3.2
# Episode =   28, score =  -3.177 (best =  -3.148), noise_scale = 3.2
# Episode =   29, score =  -3.094 (best =  -3.094), noise_scale = 1.6
# Episode =   30, score =  -3.250 (best =  -3.094), noise_scale = 3.2
# Episode =   31, score =  -3.891 (best =  -3.094), noise_scale = 3.2
# Episode =   32, score =  -4.216 (best =  -3.094), noise_scale = 3.2
# Episode =   33, score =  -3.667 (best =  -3.094), noise_scale = 3.2
# Episode =   34, score =  -3.130 (best =  -3.094), noise_scale = 3.2
# Episode =   35, score =  -2.328 (best =  -2.328), noise_scale = 1.6
# Episode =   36, score =  -3.083 (best =  -2.328), noise_scale = 3.2
# Episode =   37, score =  -3.279 (best =  -2.328), noise_scale = 3.2
# Episode =   38, score =  -2.844 (best =  -2.328), noise_scale = 3.2
# Episode =   39, score =  -2.551 (best =  -2.328), noise_scale = 3.2
# Episode =   40, score =  -2.163 (best =  -2.163), noise_scale = 1.6
# Episode =   41, score =  -3.199 (best =  -2.163), noise_scale = 3.2
# Episode =   42, score =  -3.067 (best =  -2.163), noise_scale = 3.2
# Episode =   43, score =  -3.511 (best =  -2.163), noise_scale = 3.2
# Episode =   44, score =  -3.547 (best =  -2.163), noise_scale = 3.2
# Episode =   45, score =  -3.508 (best =  -2.163), noise_scale = 3.2
# Episode =   46, score =  -3.174 (best =  -2.163), noise_scale = 3.2
# Episode =   47, score =  -3.103 (best =  -2.163), noise_scale = 3.2
# Episode =   48, score =  -3.069 (best =  -2.163), noise_scale = 3.2
# Episode =   49, score =  -3.067 (best =  -2.163), noise_scale = 3.2
# Episode =   50, score =  -3.852 (best =  -2.163), noise_scale = 3.2
# Episode =   51, score =  -3.091 (best =  -2.163), noise_scale = 3.2
# Episode =   52, score =  -3.038 (best =  -2.163), noise_scale = 3.2
# Episode =   53, score =  -3.440 (best =  -2.163), noise_scale = 3.2
# Episode =   54, score =  -3.063 (best =  -2.163), noise_scale = 3.2
# Episode =   55, score =  -3.540 (best =  -2.163), noise_scale = 3.2
# Episode =   56, score =  -3.576 (best =  -2.163), noise_scale = 3.2
# Episode =   57, score =  -2.237 (best =  -2.163), noise_scale = 3.2
# Episode =   58, score =  -3.065 (best =  -2.163), noise_scale = 3.2
# Episode =   59, score =  -3.615 (best =  -2.163), noise_scale = 3.2
# Episode =   60, score =  -3.080 (best =  -2.163), noise_scale = 3.2
# Episode =   61, score =  -5.108 (best =  -2.163), noise_scale = 3.2
# Episode =   62, score =  -3.271 (best =  -2.163), noise_scale = 3.2
# Episode =   63, score =  -3.270 (best =  -2.163), noise_scale = 3.2
# Episode =   64, score =  -3.148 (best =  -2.163), noise_scale = 3.2
# Episode =   65, score =  -3.034 (best =  -2.163), noise_scale = 3.2
# Episode =   66, score =  -2.139 (best =  -2.139), noise_scale = 1.6
# Episode =   67, score =  -2.606 (best =  -2.139), noise_scale = 3.2
# Episode =   68, score =  -4.506 (best =  -2.139), noise_scale = 3.2
# Episode =   69, score =  -2.570 (best =  -2.139), noise_scale = 3.2
# Episode =   70, score =  -3.635 (best =  -2.139), noise_scale = 3.2
# Episode =   71, score =  -3.280 (best =  -2.139), noise_scale = 3.2
# Episode =   72, score =  -3.469 (best =  -2.139), noise_scale = 3.2
# Episode =   73, score =  -3.040 (best =  -2.139), noise_scale = 3.2
# Episode =   74, score =  -3.251 (best =  -2.139), noise_scale = 3.2
# Episode =   75, score =  -3.087 (best =  -2.139), noise_scale = 3.2
# Episode =   76, score =  -2.795 (best =  -2.139), noise_scale = 3.2
# Episode =   77, score =  -3.045 (best =  -2.139), noise_scale = 3.2
# Episode =   78, score =  -2.476 (best =  -2.139), noise_scale = 3.2
# Episode =   79, score =  -3.074 (best =  -2.139), noise_scale = 3.2
# Episode =   80, score =  -3.038 (best =  -2.139), noise_scale = 3.2
# Episode =   81, score =  -3.636 (best =  -2.139), noise_scale = 3.2
# Episode =   82, score =  -3.396 (best =  -2.139), noise_scale = 3.2
# Episode =   83, score =  -3.107 (best =  -2.139), noise_scale = 3.2
# Episode =   84, score =  -2.686 (best =  -2.139), noise_scale = 3.2
# Episode =   85, score =  -3.252 (best =  -2.139), noise_scale = 3.2
# Episode =   86, score =  -1.824 (best =  -1.824), noise_scale = 1.6
# Episode =   87, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =   88, score =  -2.497 (best =  -1.824), noise_scale = 3.2
# Episode =   89, score =  -1.825 (best =  -1.824), noise_scale = 3.2
# Episode =   90, score =  -3.538 (best =  -1.824), noise_scale = 3.2
# Episode =   91, score =  -4.021 (best =  -1.824), noise_scale = 3.2
# Episode =   92, score =  -2.979 (best =  -1.824), noise_scale = 3.2
# Episode =   93, score =  -2.385 (best =  -1.824), noise_scale = 3.2
# Episode =   94, score =  -2.774 (best =  -1.824), noise_scale = 3.2
# Episode =   95, score =  -2.044 (best =  -1.824), noise_scale = 3.2
# Episode =   96, score =  -2.264 (best =  -1.824), noise_scale = 3.2
# Episode =   97, score =  -3.038 (best =  -1.824), noise_scale = 3.2
# Episode =   98, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =   99, score =  -3.580 (best =  -1.824), noise_scale = 3.2
# Episode =  100, score =  -4.765 (best =  -1.824), noise_scale = 3.2
# Episode =  101, score =  -5.126 (best =  -1.824), noise_scale = 3.2
# Episode =  102, score =  -3.688 (best =  -1.824), noise_scale = 3.2
# Episode =  103, score =  -2.789 (best =  -1.824), noise_scale = 3.2
# Episode =  104, score =  -4.341 (best =  -1.824), noise_scale = 3.2
# Episode =  105, score =  -2.225 (best =  -1.824), noise_scale = 3.2
# Episode =  106, score =  -2.391 (best =  -1.824), noise_scale = 3.2
# Episode =  107, score =  -3.546 (best =  -1.824), noise_scale = 3.2
# Episode =  108, score =  -3.256 (best =  -1.824), noise_scale = 3.2
# Episode =  109, score =  -3.807 (best =  -1.824), noise_scale = 3.2
# Episode =  110, score =  -3.714 (best =  -1.824), noise_scale = 3.2
# Episode =  111, score =  -5.249 (best =  -1.824), noise_scale = 3.2
# Episode =  112, score =  -3.087 (best =  -1.824), noise_scale = 3.2
# Episode =  113, score =  -2.634 (best =  -1.824), noise_scale = 3.2
# Episode =  114, score =  -3.347 (best =  -1.824), noise_scale = 3.2
# Episode =  115, score =  -3.909 (best =  -1.824), noise_scale = 3.2
# Episode =  116, score =  -2.878 (best =  -1.824), noise_scale = 3.2
# Episode =  117, score =  -2.710 (best =  -1.824), noise_scale = 3.2
# Episode =  118, score =  -3.042 (best =  -1.824), noise_scale = 3.2
# Episode =  119, score =  -4.325 (best =  -1.824), noise_scale = 3.2
# Episode =  120, score =  -3.243 (best =  -1.824), noise_scale = 3.2
# Episode =  121, score =  -2.309 (best =  -1.824), noise_scale = 3.2
# Episode =  122, score =  -3.031 (best =  -1.824), noise_scale = 3.2
# Episode =  123, score =  -2.684 (best =  -1.824), noise_scale = 3.2
# Episode =  124, score =  -3.174 (best =  -1.824), noise_scale = 3.2
# Episode =  125, score =  -5.442 (best =  -1.824), noise_scale = 3.2
# Episode =  126, score =  -3.342 (best =  -1.824), noise_scale = 3.2
# Episode =  127, score =  -3.364 (best =  -1.824), noise_scale = 3.2
# Episode =  128, score =  -2.757 (best =  -1.824), noise_scale = 3.2
# Episode =  129, score =  -2.868 (best =  -1.824), noise_scale = 3.2
# Episode =  130, score =  -2.077 (best =  -1.824), noise_scale = 3.2
# Episode =  131, score =  -3.953 (best =  -1.824), noise_scale = 3.2
# Episode =  132, score =  -5.117 (best =  -1.824), noise_scale = 3.2
# Episode =  133, score =  -4.000 (best =  -1.824), noise_scale = 3.2
# Episode =  134, score =  -3.499 (best =  -1.824), noise_scale = 3.2
# Episode =  135, score =  -4.586 (best =  -1.824), noise_scale = 3.2
# Episode =  136, score =  -5.252 (best =  -1.824), noise_scale = 3.2
# Episode =  137, score =  -3.134 (best =  -1.824), noise_scale = 3.2
# Episode =  138, score =  -3.167 (best =  -1.824), noise_scale = 3.2
# Episode =  139, score =  -3.045 (best =  -1.824), noise_scale = 3.2
# Episode =  140, score =  -4.597 (best =  -1.824), noise_scale = 3.2
# Episode =  141, score =  -2.835 (best =  -1.824), noise_scale = 3.2
# Episode =  142, score =  -3.486 (best =  -1.824), noise_scale = 3.2
# Episode =  143, score =  -3.107 (best =  -1.824), noise_scale = 3.2
# Episode =  144, score =  -3.408 (best =  -1.824), noise_scale = 3.2
# Episode =  145, score =  -6.200 (best =  -1.824), noise_scale = 3.2
# Episode =  146, score =  -3.617 (best =  -1.824), noise_scale = 3.2
# Episode =  147, score =  -3.179 (best =  -1.824), noise_scale = 3.2
# Episode =  148, score =  -3.641 (best =  -1.824), noise_scale = 3.2
# Episode =  149, score =  -3.120 (best =  -1.824), noise_scale = 3.2
# Episode =  150, score =  -3.169 (best =  -1.824), noise_scale = 3.2
# Episode =  151, score =  -3.058 (best =  -1.824), noise_scale = 3.2
# Episode =  152, score =  -2.272 (best =  -1.824), noise_scale = 3.2
# Episode =  153, score =  -3.636 (best =  -1.824), noise_scale = 3.2
# Episode =  154, score =  -3.143 (best =  -1.824), noise_scale = 3.2
# Episode =  155, score =  -3.107 (best =  -1.824), noise_scale = 3.2
# Episode =  156, score =  -2.548 (best =  -1.824), noise_scale = 3.2
# Episode =  157, score =  -4.139 (best =  -1.824), noise_scale = 3.2
# Episode =  158, score =  -4.596 (best =  -1.824), noise_scale = 3.2
# Episode =  159, score =  -3.154 (best =  -1.824), noise_scale = 3.2
# Episode =  160, score =  -3.692 (best =  -1.824), noise_scale = 3.2
# Episode =  161, score =  -3.225 (best =  -1.824), noise_scale = 3.2
# Episode =  162, score =  -2.682 (best =  -1.824), noise_scale = 3.2
# Episode =  163, score =  -3.456 (best =  -1.824), noise_scale = 3.2
# Episode =  164, score =  -2.967 (best =  -1.824), noise_scale = 3.2
# Episode =  165, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  166, score =  -3.786 (best =  -1.824), noise_scale = 3.2
# Episode =  167, score =  -4.426 (best =  -1.824), noise_scale = 3.2
# Episode =  168, score =  -3.036 (best =  -1.824), noise_scale = 3.2
# Episode =  169, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  170, score =  -4.032 (best =  -1.824), noise_scale = 3.2
# Episode =  171, score =  -4.113 (best =  -1.824), noise_scale = 3.2
# Episode =  172, score =  -3.638 (best =  -1.824), noise_scale = 3.2
# Episode =  173, score =  -2.248 (best =  -1.824), noise_scale = 3.2
# Episode =  174, score =  -3.277 (best =  -1.824), noise_scale = 3.2
# Episode =  175, score =  -3.368 (best =  -1.824), noise_scale = 3.2
# Episode =  176, score =  -6.073 (best =  -1.824), noise_scale = 3.2
# Episode =  177, score =  -3.606 (best =  -1.824), noise_scale = 3.2
# Episode =  178, score =  -4.372 (best =  -1.824), noise_scale = 3.2
# Episode =  179, score =  -3.056 (best =  -1.824), noise_scale = 3.2
# Episode =  180, score =  -2.725 (best =  -1.824), noise_scale = 3.2
# Episode =  181, score =  -2.830 (best =  -1.824), noise_scale = 3.2
# Episode =  182, score =  -3.682 (best =  -1.824), noise_scale = 3.2
# Episode =  183, score =  -3.213 (best =  -1.824), noise_scale = 3.2
# Episode =  184, score =  -3.455 (best =  -1.824), noise_scale = 3.2
# Episode =  185, score =  -3.114 (best =  -1.824), noise_scale = 3.2
# Episode =  186, score =  -3.199 (best =  -1.824), noise_scale = 3.2
# Episode =  187, score =  -2.496 (best =  -1.824), noise_scale = 3.2
# Episode =  188, score =  -2.313 (best =  -1.824), noise_scale = 3.2
# Episode =  189, score =  -4.105 (best =  -1.824), noise_scale = 3.2
# Episode =  190, score =  -3.384 (best =  -1.824), noise_scale = 3.2
# Episode =  191, score =  -8.242 (best =  -1.824), noise_scale = 3.2
# Episode =  192, score =  -3.042 (best =  -1.824), noise_scale = 3.2
# Episode =  193, score =  -3.513 (best =  -1.824), noise_scale = 3.2
# Episode =  194, score =  -3.673 (best =  -1.824), noise_scale = 3.2
# Episode =  195, score =  -2.517 (best =  -1.824), noise_scale = 3.2
# Episode =  196, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =  197, score =  -3.316 (best =  -1.824), noise_scale = 3.2
# Episode =  198, score =  -1.952 (best =  -1.824), noise_scale = 3.2
# Episode =  199, score =  -2.878 (best =  -1.824), noise_scale = 3.2
# Episode =  200, score =  -3.485 (best =  -1.824), noise_scale = 3.2
# Episode =  201, score =  -3.143 (best =  -1.824), noise_scale = 3.2
# Episode =  202, score =  -4.256 (best =  -1.824), noise_scale = 3.2
# Episode =  203, score =  -3.804 (best =  -1.824), noise_scale = 3.2
# Episode =  204, score =  -3.087 (best =  -1.824), noise_scale = 3.2
# Episode =  205, score =  -3.179 (best =  -1.824), noise_scale = 3.2
# Episode =  206, score =  -4.243 (best =  -1.824), noise_scale = 3.2
# Episode =  207, score =  -2.392 (best =  -1.824), noise_scale = 3.2
# Episode =  208, score =  -3.107 (best =  -1.824), noise_scale = 3.2
# Episode =  209, score =  -2.852 (best =  -1.824), noise_scale = 3.2
# Episode =  210, score =  -3.922 (best =  -1.824), noise_scale = 3.2
# Episode =  211, score =  -5.271 (best =  -1.824), noise_scale = 3.2
# Episode =  212, score =  -3.187 (best =  -1.824), noise_scale = 3.2
# Episode =  213, score =  -3.045 (best =  -1.824), noise_scale = 3.2
# Episode =  214, score =  -3.154 (best =  -1.824), noise_scale = 3.2
# Episode =  215, score =  -2.830 (best =  -1.824), noise_scale = 3.2
# Episode =  216, score =  -4.637 (best =  -1.824), noise_scale = 3.2
# Episode =  217, score =  -2.495 (best =  -1.824), noise_scale = 3.2
# Episode =  218, score =  -3.439 (best =  -1.824), noise_scale = 3.2
# Episode =  219, score =  -3.451 (best =  -1.824), noise_scale = 3.2
# Episode =  220, score =  -3.116 (best =  -1.824), noise_scale = 3.2
# Episode =  221, score =  -4.706 (best =  -1.824), noise_scale = 3.2
# Episode =  222, score =  -3.646 (best =  -1.824), noise_scale = 3.2
# Episode =  223, score =  -3.180 (best =  -1.824), noise_scale = 3.2
# Episode =  224, score =  -3.441 (best =  -1.824), noise_scale = 3.2
# Episode =  225, score =  -3.160 (best =  -1.824), noise_scale = 3.2
# Episode =  226, score =  -4.353 (best =  -1.824), noise_scale = 3.2
# Episode =  227, score =  -2.203 (best =  -1.824), noise_scale = 3.2
# Episode =  228, score =  -3.953 (best =  -1.824), noise_scale = 3.2
# Episode =  229, score =  -3.557 (best =  -1.824), noise_scale = 3.2
# Episode =  230, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  231, score =  -3.365 (best =  -1.824), noise_scale = 3.2
# Episode =  232, score =  -3.151 (best =  -1.824), noise_scale = 3.2
# Episode =  233, score =  -3.639 (best =  -1.824), noise_scale = 3.2
# Episode =  234, score =  -3.333 (best =  -1.824), noise_scale = 3.2
# Episode =  235, score =  -2.908 (best =  -1.824), noise_scale = 3.2
# Episode =  236, score =  -2.980 (best =  -1.824), noise_scale = 3.2
# Episode =  237, score =  -2.344 (best =  -1.824), noise_scale = 3.2
# Episode =  238, score =  -3.847 (best =  -1.824), noise_scale = 3.2
# Episode =  239, score =  -3.100 (best =  -1.824), noise_scale = 3.2
# Episode =  240, score =  -3.751 (best =  -1.824), noise_scale = 3.2
# Episode =  241, score =  -2.742 (best =  -1.824), noise_scale = 3.2
# Episode =  242, score =  -2.402 (best =  -1.824), noise_scale = 3.2
# Episode =  243, score =  -4.741 (best =  -1.824), noise_scale = 3.2
# Episode =  244, score =  -4.029 (best =  -1.824), noise_scale = 3.2
# Episode =  245, score =  -6.292 (best =  -1.824), noise_scale = 3.2
# Episode =  246, score =  -2.250 (best =  -1.824), noise_scale = 3.2
# Episode =  247, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  248, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =  249, score =  -3.354 (best =  -1.824), noise_scale = 3.2
# Episode =  250, score =  -3.411 (best =  -1.824), noise_scale = 3.2
# Episode =  251, score =  -4.183 (best =  -1.824), noise_scale = 3.2
# Episode =  252, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  253, score =  -3.236 (best =  -1.824), noise_scale = 3.2
# Episode =  254, score =  -3.083 (best =  -1.824), noise_scale = 3.2
# Episode =  255, score =  -3.036 (best =  -1.824), noise_scale = 3.2
# Episode =  256, score =  -4.729 (best =  -1.824), noise_scale = 3.2
# Episode =  257, score =  -4.695 (best =  -1.824), noise_scale = 3.2
# Episode =  258, score =  -3.080 (best =  -1.824), noise_scale = 3.2
# Episode =  259, score =  -4.345 (best =  -1.824), noise_scale = 3.2
# Episode =  260, score =  -3.420 (best =  -1.824), noise_scale = 3.2
# Episode =  261, score =  -4.037 (best =  -1.824), noise_scale = 3.2
# Episode =  262, score =  -3.122 (best =  -1.824), noise_scale = 3.2
# Episode =  263, score =  -5.144 (best =  -1.824), noise_scale = 3.2
# Episode =  264, score =  -4.183 (best =  -1.824), noise_scale = 3.2
# Episode =  265, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =  266, score =  -2.728 (best =  -1.824), noise_scale = 3.2
# Episode =  267, score =  -3.080 (best =  -1.824), noise_scale = 3.2
# Episode =  268, score =  -3.249 (best =  -1.824), noise_scale = 3.2
# Episode =  269, score =  -3.654 (best =  -1.824), noise_scale = 3.2
# Episode =  270, score =  -3.355 (best =  -1.824), noise_scale = 3.2
# Episode =  271, score =  -2.442 (best =  -1.824), noise_scale = 3.2
# Episode =  272, score =  -2.413 (best =  -1.824), noise_scale = 3.2
# Episode =  273, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  274, score =  -3.088 (best =  -1.824), noise_scale = 3.2
# Episode =  275, score =  -3.526 (best =  -1.824), noise_scale = 3.2
# Episode =  276, score =  -2.566 (best =  -1.824), noise_scale = 3.2
# Episode =  277, score =  -3.087 (best =  -1.824), noise_scale = 3.2
# Episode =  278, score =  -3.150 (best =  -1.824), noise_scale = 3.2
# Episode =  279, score =  -3.198 (best =  -1.824), noise_scale = 3.2
# Episode =  280, score =  -2.530 (best =  -1.824), noise_scale = 3.2
# Episode =  281, score =  -3.116 (best =  -1.824), noise_scale = 3.2
# Episode =  282, score =  -3.037 (best =  -1.824), noise_scale = 3.2
# Episode =  283, score =  -3.185 (best =  -1.824), noise_scale = 3.2
# Episode =  284, score =  -3.131 (best =  -1.824), noise_scale = 3.2
# Episode =  285, score =  -3.406 (best =  -1.824), noise_scale = 3.2
# Episode =  286, score =  -2.709 (best =  -1.824), noise_scale = 3.2
# Episode =  287, score =  -3.945 (best =  -1.824), noise_scale = 3.2
# Episode =  288, score =  -3.062 (best =  -1.824), noise_scale = 3.2
# Episode =  289, score =  -2.844 (best =  -1.824), noise_scale = 3.2
# Episode =  290, score =  -3.802 (best =  -1.824), noise_scale = 3.2
# Episode =  291, score =  -3.161 (best =  -1.824), noise_scale = 3.2
# Episode =  292, score =  -5.787 (best =  -1.824), noise_scale = 3.2
# Episode =  293, score =  -3.040 (best =  -1.824), noise_scale = 3.2
# Episode =  294, score =  -3.399 (best =  -1.824), noise_scale = 3.2
# Episode =  295, score =  -3.224 (best =  -1.824), noise_scale = 3.2
# Episode =  296, score =  -3.645 (best =  -1.824), noise_scale = 3.2
# Episode =  297, score =  -3.818 (best =  -1.824), noise_scale = 3.2
# Episode =  298, score =  -3.193 (best =  -1.824), noise_scale = 3.2
# Episode =  299, score =  -3.071 (best =  -1.824), noise_scale = 3.2
# Episode =  300, score =  -3.199 (best =  -1.824), noise_scale = 3.2
# Episode =  301, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  302, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  303, score =  -2.939 (best =  -1.824), noise_scale = 3.2
# Episode =  304, score =  -3.141 (best =  -1.824), noise_scale = 3.2
# Episode =  305, score =  -3.218 (best =  -1.824), noise_scale = 3.2
# Episode =  306, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  307, score =  -3.754 (best =  -1.824), noise_scale = 3.2
# Episode =  308, score =  -2.943 (best =  -1.824), noise_scale = 3.2
# Episode =  309, score =  -2.711 (best =  -1.824), noise_scale = 3.2
# Episode =  310, score =  -2.807 (best =  -1.824), noise_scale = 3.2
# Episode =  311, score =  -3.453 (best =  -1.824), noise_scale = 3.2
# Episode =  312, score =  -3.149 (best =  -1.824), noise_scale = 3.2
# Episode =  313, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  314, score =  -3.651 (best =  -1.824), noise_scale = 3.2
# Episode =  315, score =  -3.365 (best =  -1.824), noise_scale = 3.2
# Episode =  316, score =  -3.915 (best =  -1.824), noise_scale = 3.2
# Episode =  317, score =  -3.809 (best =  -1.824), noise_scale = 3.2
# Episode =  318, score =  -3.215 (best =  -1.824), noise_scale = 3.2
# Episode =  319, score =  -3.450 (best =  -1.824), noise_scale = 3.2
# Episode =  320, score =  -3.916 (best =  -1.824), noise_scale = 3.2
# Episode =  321, score =  -2.274 (best =  -1.824), noise_scale = 3.2
# Episode =  322, score =  -2.648 (best =  -1.824), noise_scale = 3.2
# Episode =  323, score =  -3.294 (best =  -1.824), noise_scale = 3.2
# Episode =  324, score =  -3.260 (best =  -1.824), noise_scale = 3.2
# Episode =  325, score =  -3.600 (best =  -1.824), noise_scale = 3.2
# Episode =  326, score =  -3.195 (best =  -1.824), noise_scale = 3.2
# Episode =  327, score =  -4.019 (best =  -1.824), noise_scale = 3.2
# Episode =  328, score =  -2.284 (best =  -1.824), noise_scale = 3.2
# Episode =  329, score =  -4.331 (best =  -1.824), noise_scale = 3.2
# Episode =  330, score =  -2.621 (best =  -1.824), noise_scale = 3.2
# Episode =  331, score =  -3.737 (best =  -1.824), noise_scale = 3.2
# Episode =  332, score =  -3.038 (best =  -1.824), noise_scale = 3.2
# Episode =  333, score =  -3.040 (best =  -1.824), noise_scale = 3.2
# Episode =  334, score =  -3.442 (best =  -1.824), noise_scale = 3.2
# Episode =  335, score =  -3.286 (best =  -1.824), noise_scale = 3.2
# Episode =  336, score =  -3.471 (best =  -1.824), noise_scale = 3.2
# Episode =  337, score =  -2.411 (best =  -1.824), noise_scale = 3.2
# Episode =  338, score =  -2.639 (best =  -1.824), noise_scale = 3.2
# Episode =  339, score =  -3.376 (best =  -1.824), noise_scale = 3.2
# Episode =  340, score =  -4.876 (best =  -1.824), noise_scale = 3.2
# Episode =  341, score =  -3.297 (best =  -1.824), noise_scale = 3.2
# Episode =  342, score =  -3.606 (best =  -1.824), noise_scale = 3.2
# Episode =  343, score =  -3.120 (best =  -1.824), noise_scale = 3.2
# Episode =  344, score =  -3.031 (best =  -1.824), noise_scale = 3.2
# Episode =  345, score =  -4.679 (best =  -1.824), noise_scale = 3.2
# Episode =  346, score =  -3.785 (best =  -1.824), noise_scale = 3.2
# Episode =  347, score =  -5.388 (best =  -1.824), noise_scale = 3.2
# Episode =  348, score =  -2.645 (best =  -1.824), noise_scale = 3.2
# Episode =  349, score =  -3.782 (best =  -1.824), noise_scale = 3.2
# Episode =  350, score =  -4.931 (best =  -1.824), noise_scale = 3.2
# Episode =  351, score =  -3.507 (best =  -1.824), noise_scale = 3.2
# Episode =  352, score =  -3.145 (best =  -1.824), noise_scale = 3.2
# Episode =  353, score =  -4.572 (best =  -1.824), noise_scale = 3.2
# Episode =  354, score =  -2.953 (best =  -1.824), noise_scale = 3.2
# Episode =  355, score =  -3.399 (best =  -1.824), noise_scale = 3.2
# Episode =  356, score =  -4.044 (best =  -1.824), noise_scale = 3.2
# Episode =  357, score =  -3.131 (best =  -1.824), noise_scale = 3.2
# Episode =  358, score =  -2.249 (best =  -1.824), noise_scale = 3.2
# Episode =  359, score =  -3.247 (best =  -1.824), noise_scale = 3.2
# Episode =  360, score =  -2.639 (best =  -1.824), noise_scale = 3.2
# Episode =  361, score =  -2.549 (best =  -1.824), noise_scale = 3.2
# Episode =  362, score =  -2.338 (best =  -1.824), noise_scale = 3.2
# Episode =  363, score =  -3.828 (best =  -1.824), noise_scale = 3.2
# Episode =  364, score =  -3.036 (best =  -1.824), noise_scale = 3.2
# Episode =  365, score =  -3.117 (best =  -1.824), noise_scale = 3.2
# Episode =  366, score =  -3.083 (best =  -1.824), noise_scale = 3.2
# Episode =  367, score =  -3.734 (best =  -1.824), noise_scale = 3.2
# Episode =  368, score =  -3.879 (best =  -1.824), noise_scale = 3.2
# Episode =  369, score =  -3.037 (best =  -1.824), noise_scale = 3.2
# Episode =  370, score =  -3.520 (best =  -1.824), noise_scale = 3.2
# Episode =  371, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  372, score =  -3.340 (best =  -1.824), noise_scale = 3.2
# Episode =  373, score =  -3.643 (best =  -1.824), noise_scale = 3.2
# Episode =  374, score =  -3.793 (best =  -1.824), noise_scale = 3.2
# Episode =  375, score =  -3.235 (best =  -1.824), noise_scale = 3.2
# Episode =  376, score =  -3.078 (best =  -1.824), noise_scale = 3.2
# Episode =  377, score =  -2.808 (best =  -1.824), noise_scale = 3.2
# Episode =  378, score =  -2.850 (best =  -1.824), noise_scale = 3.2
# Episode =  379, score =  -3.325 (best =  -1.824), noise_scale = 3.2
# Episode =  380, score =  -3.042 (best =  -1.824), noise_scale = 3.2
# Episode =  381, score =  -2.410 (best =  -1.824), noise_scale = 3.2
# Episode =  382, score =  -3.728 (best =  -1.824), noise_scale = 3.2
# Episode =  383, score =  -3.966 (best =  -1.824), noise_scale = 3.2
# Episode =  384, score =  -3.526 (best =  -1.824), noise_scale = 3.2
# Episode =  385, score =  -3.925 (best =  -1.824), noise_scale = 3.2
# Episode =  386, score =  -4.038 (best =  -1.824), noise_scale = 3.2
# Episode =  387, score =  -3.883 (best =  -1.824), noise_scale = 3.2
# Episode =  388, score =  -2.862 (best =  -1.824), noise_scale = 3.2
# Episode =  389, score =  -3.476 (best =  -1.824), noise_scale = 3.2
# Episode =  390, score =  -2.888 (best =  -1.824), noise_scale = 3.2
# Episode =  391, score =  -3.037 (best =  -1.824), noise_scale = 3.2
# Episode =  392, score =  -4.387 (best =  -1.824), noise_scale = 3.2
# Episode =  393, score =  -3.152 (best =  -1.824), noise_scale = 3.2
# Episode =  394, score =  -4.276 (best =  -1.824), noise_scale = 3.2
# Episode =  395, score =  -2.557 (best =  -1.824), noise_scale = 3.2
# Episode =  396, score =  -2.397 (best =  -1.824), noise_scale = 3.2
# Episode =  397, score =  -4.470 (best =  -1.824), noise_scale = 3.2
# Episode =  398, score =  -2.206 (best =  -1.824), noise_scale = 3.2
# Episode =  399, score =  -4.148 (best =  -1.824), noise_scale = 3.2
# Episode =  400, score =  -3.838 (best =  -1.824), noise_scale = 3.2
# Episode =  401, score =  -2.375 (best =  -1.824), noise_scale = 3.2
# Episode =  402, score =  -3.069 (best =  -1.824), noise_scale = 3.2
# Episode =  403, score =  -3.261 (best =  -1.824), noise_scale = 3.2
# Episode =  404, score =  -4.777 (best =  -1.824), noise_scale = 3.2
# Episode =  405, score =  -3.580 (best =  -1.824), noise_scale = 3.2
# Episode =  406, score =  -3.120 (best =  -1.824), noise_scale = 3.2
# Episode =  407, score =  -3.859 (best =  -1.824), noise_scale = 3.2
# Episode =  408, score =  -2.628 (best =  -1.824), noise_scale = 3.2
# Episode =  409, score =  -4.010 (best =  -1.824), noise_scale = 3.2
# Episode =  410, score =  -2.613 (best =  -1.824), noise_scale = 3.2
# Episode =  411, score =  -3.554 (best =  -1.824), noise_scale = 3.2
# Episode =  412, score =  -3.363 (best =  -1.824), noise_scale = 3.2
# Episode =  413, score =  -2.097 (best =  -1.824), noise_scale = 3.2
# Episode =  414, score =  -3.179 (best =  -1.824), noise_scale = 3.2
# Episode =  415, score =  -3.193 (best =  -1.824), noise_scale = 3.2
# Episode =  416, score =  -3.069 (best =  -1.824), noise_scale = 3.2
# Episode =  417, score =  -3.325 (best =  -1.824), noise_scale = 3.2
# Episode =  418, score =  -2.338 (best =  -1.824), noise_scale = 3.2
# Episode =  419, score =  -3.669 (best =  -1.824), noise_scale = 3.2
# Episode =  420, score =  -3.581 (best =  -1.824), noise_scale = 3.2
# Episode =  421, score =  -3.412 (best =  -1.824), noise_scale = 3.2
# Episode =  422, score =  -4.454 (best =  -1.824), noise_scale = 3.2
# Episode =  423, score =  -2.098 (best =  -1.824), noise_scale = 3.2
# Episode =  424, score =  -3.719 (best =  -1.824), noise_scale = 3.2
# Episode =  425, score =  -3.071 (best =  -1.824), noise_scale = 3.2
# Episode =  426, score =  -3.482 (best =  -1.824), noise_scale = 3.2
# Episode =  427, score =  -3.594 (best =  -1.824), noise_scale = 3.2
# Episode =  428, score =  -4.246 (best =  -1.824), noise_scale = 3.2
# Episode =  429, score =  -3.040 (best =  -1.824), noise_scale = 3.2
# Episode =  430, score =  -3.159 (best =  -1.824), noise_scale = 3.2
# Episode =  431, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  432, score =  -3.807 (best =  -1.824), noise_scale = 3.2
# Episode =  433, score =  -2.829 (best =  -1.824), noise_scale = 3.2
# Episode =  434, score =  -3.137 (best =  -1.824), noise_scale = 3.2
# Episode =  435, score =  -3.158 (best =  -1.824), noise_scale = 3.2
# Episode =  436, score =  -2.437 (best =  -1.824), noise_scale = 3.2
# Episode =  437, score =  -2.950 (best =  -1.824), noise_scale = 3.2
# Episode =  438, score =  -3.129 (best =  -1.824), noise_scale = 3.2
# Episode =  439, score =  -3.456 (best =  -1.824), noise_scale = 3.2
# Episode =  440, score =  -4.225 (best =  -1.824), noise_scale = 3.2
# Episode =  441, score =  -3.878 (best =  -1.824), noise_scale = 3.2
# Episode =  442, score =  -2.602 (best =  -1.824), noise_scale = 3.2
# Episode =  443, score =  -4.249 (best =  -1.824), noise_scale = 3.2
# Episode =  444, score =  -3.486 (best =  -1.824), noise_scale = 3.2
# Episode =  445, score =  -3.225 (best =  -1.824), noise_scale = 3.2
# Episode =  446, score =  -2.317 (best =  -1.824), noise_scale = 3.2
# Episode =  447, score =  -4.055 (best =  -1.824), noise_scale = 3.2
# Episode =  448, score =  -3.412 (best =  -1.824), noise_scale = 3.2
# Episode =  449, score =  -3.304 (best =  -1.824), noise_scale = 3.2
# Episode =  450, score =  -2.243 (best =  -1.824), noise_scale = 3.2
# Episode =  451, score =  -2.054 (best =  -1.824), noise_scale = 3.2
# Episode =  452, score =  -3.069 (best =  -1.824), noise_scale = 3.2
# Episode =  453, score =  -3.717 (best =  -1.824), noise_scale = 3.2
# Episode =  454, score =  -3.384 (best =  -1.824), noise_scale = 3.2
# Episode =  455, score =  -2.329 (best =  -1.824), noise_scale = 3.2
# Episode =  456, score =  -3.754 (best =  -1.824), noise_scale = 3.2
# Episode =  457, score =  -3.042 (best =  -1.824), noise_scale = 3.2
# Episode =  458, score =  -3.450 (best =  -1.824), noise_scale = 3.2
# Episode =  459, score =  -3.331 (best =  -1.824), noise_scale = 3.2
# Episode =  460, score =  -1.866 (best =  -1.824), noise_scale = 3.2
# Episode =  461, score =  -3.674 (best =  -1.824), noise_scale = 3.2
# Episode =  462, score =  -3.114 (best =  -1.824), noise_scale = 3.2
# Episode =  463, score =  -3.759 (best =  -1.824), noise_scale = 3.2
# Episode =  464, score =  -3.883 (best =  -1.824), noise_scale = 3.2
# Episode =  465, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  466, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  467, score =  -2.662 (best =  -1.824), noise_scale = 3.2
# Episode =  468, score =  -3.740 (best =  -1.824), noise_scale = 3.2
# Episode =  469, score =  -3.148 (best =  -1.824), noise_scale = 3.2
# Episode =  470, score =  -3.735 (best =  -1.824), noise_scale = 3.2
# Episode =  471, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  472, score =  -4.277 (best =  -1.824), noise_scale = 3.2
# Episode =  473, score =  -3.502 (best =  -1.824), noise_scale = 3.2
# Episode =  474, score =  -2.686 (best =  -1.824), noise_scale = 3.2
# Episode =  475, score =  -2.402 (best =  -1.824), noise_scale = 3.2
# Episode =  476, score =  -4.136 (best =  -1.824), noise_scale = 3.2
# Episode =  477, score =  -3.337 (best =  -1.824), noise_scale = 3.2
# Episode =  478, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =  479, score =  -3.756 (best =  -1.824), noise_scale = 3.2
# Episode =  480, score =  -3.666 (best =  -1.824), noise_scale = 3.2
# Episode =  481, score =  -3.802 (best =  -1.824), noise_scale = 3.2
# Episode =  482, score =  -3.503 (best =  -1.824), noise_scale = 3.2
# Episode =  483, score =  -4.132 (best =  -1.824), noise_scale = 3.2
# Episode =  484, score =  -3.960 (best =  -1.824), noise_scale = 3.2
# Episode =  485, score =  -6.754 (best =  -1.824), noise_scale = 3.2
# Episode =  486, score =  -2.471 (best =  -1.824), noise_scale = 3.2
# Episode =  487, score =  -3.943 (best =  -1.824), noise_scale = 3.2
# Episode =  488, score =  -3.032 (best =  -1.824), noise_scale = 3.2
# Episode =  489, score =  -2.964 (best =  -1.824), noise_scale = 3.2
# Episode =  490, score =  -3.129 (best =  -1.824), noise_scale = 3.2
# Episode =  491, score =  -2.665 (best =  -1.824), noise_scale = 3.2
# Episode =  492, score =  -4.131 (best =  -1.824), noise_scale = 3.2
# Episode =  493, score =  -3.038 (best =  -1.824), noise_scale = 3.2
# Episode =  494, score =  -3.228 (best =  -1.824), noise_scale = 3.2
# Episode =  495, score =  -3.220 (best =  -1.824), noise_scale = 3.2
# Episode =  496, score =  -3.257 (best =  -1.824), noise_scale = 3.2
# Episode =  497, score =  -3.148 (best =  -1.824), noise_scale = 3.2
# Episode =  498, score =  -4.652 (best =  -1.824), noise_scale = 3.2
# Episode =  499, score =  -2.849 (best =  -1.824), noise_scale = 3.2
# Episode =  500, score =  -3.887 (best =  -1.824), noise_scale = 3.2
# Episode =  501, score =  -2.957 (best =  -1.824), noise_scale = 3.2
# Episode =  502, score =  -3.498 (best =  -1.824), noise_scale = 3.2
# Episode =  503, score =  -3.280 (best =  -1.824), noise_scale = 3.2
# Episode =  504, score =  -3.404 (best =  -1.824), noise_scale = 3.2
# Episode =  505, score =  -3.069 (best =  -1.824), noise_scale = 3.2
# Episode =  506, score =  -3.381 (best =  -1.824), noise_scale = 3.2
# Episode =  507, score =  -3.424 (best =  -1.824), noise_scale = 3.2
# Episode =  508, score =  -3.350 (best =  -1.824), noise_scale = 3.2
# Episode =  509, score =  -2.437 (best =  -1.824), noise_scale = 3.2
# Episode =  510, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  511, score =  -3.231 (best =  -1.824), noise_scale = 3.2
# Episode =  512, score =  -3.575 (best =  -1.824), noise_scale = 3.2
# Episode =  513, score =  -3.205 (best =  -1.824), noise_scale = 3.2
# Episode =  514, score =  -2.552 (best =  -1.824), noise_scale = 3.2
# Episode =  515, score =  -2.993 (best =  -1.824), noise_scale = 3.2
# Episode =  516, score =  -1.885 (best =  -1.824), noise_scale = 3.2
# Episode =  517, score =  -3.211 (best =  -1.824), noise_scale = 3.2
# Episode =  518, score =  -3.160 (best =  -1.824), noise_scale = 3.2
# Episode =  519, score =  -3.032 (best =  -1.824), noise_scale = 3.2
# Episode =  520, score =  -3.228 (best =  -1.824), noise_scale = 3.2
# Episode =  521, score =  -3.040 (best =  -1.824), noise_scale = 3.2
# Episode =  522, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  523, score =  -3.997 (best =  -1.824), noise_scale = 3.2
# Episode =  524, score =  -4.294 (best =  -1.824), noise_scale = 3.2
# Episode =  525, score =  -4.776 (best =  -1.824), noise_scale = 3.2
# Episode =  526, score =  -4.428 (best =  -1.824), noise_scale = 3.2
# Episode =  527, score =  -5.455 (best =  -1.824), noise_scale = 3.2
# Episode =  528, score =  -3.185 (best =  -1.824), noise_scale = 3.2
# Episode =  529, score =  -3.866 (best =  -1.824), noise_scale = 3.2
# Episode =  530, score =  -3.074 (best =  -1.824), noise_scale = 3.2
# Episode =  531, score =  -3.083 (best =  -1.824), noise_scale = 3.2
# Episode =  532, score =  -3.134 (best =  -1.824), noise_scale = 3.2
# Episode =  533, score =  -3.125 (best =  -1.824), noise_scale = 3.2
# Episode =  534, score =  -3.190 (best =  -1.824), noise_scale = 3.2
# Episode =  535, score =  -4.169 (best =  -1.824), noise_scale = 3.2
# Episode =  536, score =  -3.045 (best =  -1.824), noise_scale = 3.2
# Episode =  537, score =  -3.228 (best =  -1.824), noise_scale = 3.2
# Episode =  538, score =  -2.676 (best =  -1.824), noise_scale = 3.2
# Episode =  539, score =  -3.783 (best =  -1.824), noise_scale = 3.2
# Episode =  540, score =  -3.131 (best =  -1.824), noise_scale = 3.2
# Episode =  541, score =  -2.218 (best =  -1.824), noise_scale = 3.2
# Episode =  542, score =  -2.441 (best =  -1.824), noise_scale = 3.2
# Episode =  543, score =  -2.040 (best =  -1.824), noise_scale = 3.2
# Episode =  544, score =  -4.447 (best =  -1.824), noise_scale = 3.2
# Episode =  545, score =  -4.368 (best =  -1.824), noise_scale = 3.2
# Episode =  546, score =  -3.945 (best =  -1.824), noise_scale = 3.2
# Episode =  547, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  548, score =  -2.490 (best =  -1.824), noise_scale = 3.2
# Episode =  549, score =  -3.042 (best =  -1.824), noise_scale = 3.2
# Episode =  550, score =  -3.338 (best =  -1.824), noise_scale = 3.2
# Episode =  551, score =  -3.655 (best =  -1.824), noise_scale = 3.2
# Episode =  552, score =  -3.192 (best =  -1.824), noise_scale = 3.2
# Episode =  553, score =  -2.000 (best =  -1.824), noise_scale = 3.2
# Episode =  554, score =  -3.038 (best =  -1.824), noise_scale = 3.2
# Episode =  555, score =  -3.100 (best =  -1.824), noise_scale = 3.2
# Episode =  556, score =  -3.421 (best =  -1.824), noise_scale = 3.2
# Episode =  557, score =  -3.364 (best =  -1.824), noise_scale = 3.2
# Episode =  558, score =  -3.065 (best =  -1.824), noise_scale = 3.2
# Episode =  559, score =  -3.111 (best =  -1.824), noise_scale = 3.2
# Episode =  560, score =  -3.167 (best =  -1.824), noise_scale = 3.2
# Episode =  561, score =  -4.069 (best =  -1.824), noise_scale = 3.2
# Episode =  562, score =  -4.029 (best =  -1.824), noise_scale = 3.2
# Episode =  563, score =  -2.955 (best =  -1.824), noise_scale = 3.2
# Episode =  564, score =  -3.439 (best =  -1.824), noise_scale = 3.2
# Episode =  565, score =  -3.378 (best =  -1.824), noise_scale = 3.2
# Episode =  566, score =  -3.385 (best =  -1.824), noise_scale = 3.2
# Episode =  567, score =  -3.445 (best =  -1.824), noise_scale = 3.2
# Episode =  568, score =  -2.434 (best =  -1.824), noise_scale = 3.2
# Episode =  569, score =  -3.154 (best =  -1.824), noise_scale = 3.2
# Episode =  570, score =  -3.357 (best =  -1.824), noise_scale = 3.2
# Episode =  571, score =  -3.715 (best =  -1.824), noise_scale = 3.2
# Episode =  572, score =  -3.034 (best =  -1.824), noise_scale = 3.2
# Episode =  573, score =  -2.186 (best =  -1.824), noise_scale = 3.2
# Episode =  574, score =  -3.069 (best =  -1.824), noise_scale = 3.2
# Episode =  575, score =  -3.087 (best =  -1.824), noise_scale = 3.2
# Episode =  576, score =  -4.646 (best =  -1.824), noise_scale = 3.2
# Episode =  577, score =  -3.596 (best =  -1.824), noise_scale = 3.2
# Episode =  578, score =  -2.510 (best =  -1.824), noise_scale = 3.2
# Episode =  579, score =  -4.569 (best =  -1.824), noise_scale = 3.2
# Episode =  580, score =  -3.043 (best =  -1.824), noise_scale = 3.2
# Episode =  581, score =  -3.171 (best =  -1.824), noise_scale = 3.2
# Episode =  582, score =  -2.279 (best =  -1.824), noise_scale = 3.2
# Episode =  583, score =  -3.100 (best =  -1.824), noise_scale = 3.2
# Episode =  584, score =  -2.757 (best =  -1.824), noise_scale = 3.2
# Episode =  585, score =  -3.231 (best =  -1.824), noise_scale = 3.2
# Episode =  586, score =  -3.037 (best =  -1.824), noise_scale = 3.2
# Episode =  587, score =  -2.534 (best =  -1.824), noise_scale = 3.2
# Episode =  588, score =  -3.077 (best =  -1.824), noise_scale = 3.2
# Episode =  589, score =  -3.115 (best =  -1.824), noise_scale = 3.2
# Episode =  590, score =  -3.113 (best =  -1.824), noise_scale = 3.2
# Episode =  591, score =  -3.027 (best =  -1.824), noise_scale = 3.2
# Episode =  592, score =  -5.248 (best =  -1.824), noise_scale = 3.2
# Episode =  593, score =  -3.826 (best =  -1.824), noise_scale = 3.2
# Episode =  594, score =  -3.356 (best =  -1.824), noise_scale = 3.2
# Episode =  595, score =  -3.251 (best =  -1.824), noise_scale = 3.2
# Episode =  596, score =  -3.080 (best =  -1.824), noise_scale = 3.2
# Episode =  597, score =  -2.307 (best =  -1.824), noise_scale = 3.2
# Episode =  598, score =  -3.573 (best =  -1.824), noise_scale = 3.2
# Episode =  599, score =  -3.145 (best =  -1.824), noise_scale = 3.2
# Episode =  600, score =  -3.167 (best =  -1.824), noise_scale = 3.2
# Episode =  601, score =  -3.251 (best =  -1.824), noise_scale = 3.2
# Episode =  602, score =  -2.461 (best =  -1.824), noise_scale = 3.2
# Episode =  603, score =  -2.887 (best =  -1.824), noise_scale = 3.2
# Episode =  604, score =  -3.217 (best =  -1.824), noise_scale = 3.2
# Episode =  605, score =  -2.929 (best =  -1.824), noise_scale = 3.2
# Episode =  606, score =  -3.224 (best =  -1.824), noise_scale = 3.2
# Episode =  607, score =  -3.486 (best =  -1.824), noise_scale = 3.2
# Episode =  608, score =  -4.274 (best =  -1.824), noise_scale = 3.2
# Episode =  609, score =  -3.798 (best =  -1.824), noise_scale = 3.2
# Episode =  610, score =  -3.063 (best =  -1.824), noise_scale = 3.2
# Episode =  611, score =  -2.444 (best =  -1.824), noise_scale = 3.2
# Episode =  612, score =  -3.284 (best =  -1.824), noise_scale = 3.2
# Episode =  613, score =  -4.528 (best =  -1.824), noise_scale = 3.2
# Episode =  614, score =  -3.467 (best =  -1.824), noise_scale = 3.2
# Episode =  615, score =  -3.273 (best =  -1.824), noise_scale = 3.2
# Episode =  616, score =  -2.666 (best =  -1.824), noise_scale = 3.2
# Episode =  617, score =  -2.695 (best =  -1.824), noise_scale = 3.2
# Episode =  618, score =  -3.082 (best =  -1.824), noise_scale = 3.2
# Episode =  619, score =  -5.114 (best =  -1.824), noise_scale = 3.2
# Episode =  620, score =  -3.072 (best =  -1.824), noise_scale = 3.2
# Episode =  621, score =  -3.077 (best =  -1.824), noise_scale = 3.2
# Episode =  622, score =  -3.624 (best =  -1.824), noise_scale = 3.2
# Episode =  623, score =  -4.228 (best =  -1.824), noise_scale = 3.2
# Episode =  624, score =  -2.777 (best =  -1.824), noise_scale = 3.2
# Episode =  625, score =  -4.275 (best =  -1.824), noise_scale = 3.2
# Episode =  626, score =  -3.037 (best =  -1.824), noise_scale = 3.2
# Episode =  627, score =  -2.540 (best =  -1.824), noise_scale = 3.2
# Episode =  628, score =  -3.077 (best =  -1.824), noise_scale = 3.2
# Episode =  629, score =  -3.091 (best =  -1.824), noise_scale = 3.2
# Episode =  630, score =  -4.795 (best =  -1.824), noise_scale = 3.2
# Episode =  631, score =  -3.630 (best =  -1.824), noise_scale = 3.2
# Episode =  632, score =  -2.715 (best =  -1.824), noise_scale = 3.2
# Episode =  633, score =  -3.120 (best =  -1.824), noise_scale = 3.2
# Episode =  634, score =  -3.024 (best =  -1.824), noise_scale = 3.2
# Episode =  635, score =  -1.709 (best =  -1.709), noise_scale = 1.6
# Episode =  636, score =  -2.656 (best =  -1.709), noise_scale = 3.2
# Episode =  637, score =  -3.381 (best =  -1.709), noise_scale = 3.2
# Episode =  638, score =  -2.910 (best =  -1.709), noise_scale = 3.2
# Episode =  639, score =  -3.620 (best =  -1.709), noise_scale = 3.2
# Episode =  640, score =  -2.305 (best =  -1.709), noise_scale = 3.2
# Episode =  641, score =  -3.806 (best =  -1.709), noise_scale = 3.2
# Episode =  642, score =  -3.452 (best =  -1.709), noise_scale = 3.2
# Episode =  643, score =  -3.191 (best =  -1.709), noise_scale = 3.2
# Episode =  644, score =  -3.080 (best =  -1.709), noise_scale = 3.2
# Episode =  645, score =  -3.080 (best =  -1.709), noise_scale = 3.2
# Episode =  646, score =  -2.101 (best =  -1.709), noise_scale = 3.2
# Episode =  647, score =  -4.200 (best =  -1.709), noise_scale = 3.2
# Episode =  648, score =  -3.223 (best =  -1.709), noise_scale = 3.2
# Episode =  649, score =  -4.162 (best =  -1.709), noise_scale = 3.2
# Episode =  650, score =  -3.184 (best =  -1.709), noise_scale = 3.2
# Episode =  651, score =  -3.413 (best =  -1.709), noise_scale = 3.2
# Episode =  652, score =  -3.037 (best =  -1.709), noise_scale = 3.2
# Episode =  653, score =  -3.688 (best =  -1.709), noise_scale = 3.2
# Episode =  654, score =  -3.486 (best =  -1.709), noise_scale = 3.2
# Episode =  655, score =  -3.081 (best =  -1.709), noise_scale = 3.2
# Episode =  656, score =  -4.281 (best =  -1.709), noise_scale = 3.2
# Episode =  657, score =  -3.042 (best =  -1.709), noise_scale = 3.2
# Episode =  658, score =  -3.111 (best =  -1.709), noise_scale = 3.2
# Episode =  659, score =  -3.167 (best =  -1.709), noise_scale = 3.2
# Episode =  660, score =  -3.211 (best =  -1.709), noise_scale = 3.2
# Episode =  661, score =  -4.409 (best =  -1.709), noise_scale = 3.2
# Episode =  662, score =  -3.767 (best =  -1.709), noise_scale = 3.2
# Episode =  663, score =  -2.592 (best =  -1.709), noise_scale = 3.2
# Episode =  664, score =  -4.886 (best =  -1.709), noise_scale = 3.2
# Episode =  665, score =  -3.709 (best =  -1.709), noise_scale = 3.2
# Episode =  666, score =  -3.087 (best =  -1.709), noise_scale = 3.2
# Episode =  667, score =  -3.071 (best =  -1.709), noise_scale = 3.2
# Episode =  668, score =  -3.134 (best =  -1.709), noise_scale = 3.2
# Episode =  669, score =  -3.854 (best =  -1.709), noise_scale = 3.2
# Episode =  670, score =  -3.529 (best =  -1.709), noise_scale = 3.2
# Episode =  671, score =  -4.338 (best =  -1.709), noise_scale = 3.2
# Episode =  672, score =  -3.120 (best =  -1.709), noise_scale = 3.2
# Episode =  673, score =  -3.831 (best =  -1.709), noise_scale = 3.2
# Episode =  674, score =  -3.668 (best =  -1.709), noise_scale = 3.2
# Episode =  675, score =  -4.719 (best =  -1.709), noise_scale = 3.2
# Episode =  676, score =  -3.496 (best =  -1.709), noise_scale = 3.2
# Episode =  677, score =  -3.448 (best =  -1.709), noise_scale = 3.2
# Episode =  678, score =  -3.093 (best =  -1.709), noise_scale = 3.2
# Episode =  679, score =  -2.584 (best =  -1.709), noise_scale = 3.2
# Episode =  680, score =  -3.187 (best =  -1.709), noise_scale = 3.2
# Episode =  681, score =  -3.379 (best =  -1.709), noise_scale = 3.2
# Episode =  682, score =  -3.032 (best =  -1.709), noise_scale = 3.2
# Episode =  683, score =  -3.034 (best =  -1.709), noise_scale = 3.2
# Episode =  684, score =  -2.793 (best =  -1.709), noise_scale = 3.2
# Episode =  685, score =  -3.805 (best =  -1.709), noise_scale = 3.2
# Episode =  686, score =  -5.418 (best =  -1.709), noise_scale = 3.2
# Episode =  687, score =  -2.315 (best =  -1.709), noise_scale = 3.2
# Episode =  688, score =  -3.506 (best =  -1.709), noise_scale = 3.2
# Episode =  689, score =  -3.982 (best =  -1.709), noise_scale = 3.2
# Episode =  690, score =  -3.146 (best =  -1.709), noise_scale = 3.2
# Episode =  691, score =  -2.285 (best =  -1.709), noise_scale = 3.2
# Episode =  692, score =  -3.312 (best =  -1.709), noise_scale = 3.2
# Episode =  693, score =  -3.083 (best =  -1.709), noise_scale = 3.2
# Episode =  694, score =  -3.038 (best =  -1.709), noise_scale = 3.2
# Episode =  695, score =  -3.167 (best =  -1.709), noise_scale = 3.2
# Episode =  696, score =  -3.309 (best =  -1.709), noise_scale = 3.2
# Episode =  697, score =  -4.197 (best =  -1.709), noise_scale = 3.2
# Episode =  698, score =  -3.879 (best =  -1.709), noise_scale = 3.2
# Episode =  699, score =  -3.120 (best =  -1.709), noise_scale = 3.2
# Episode =  700, score =  -2.905 (best =  -1.709), noise_scale = 3.2
# Episode =  701, score =  -3.348 (best =  -1.709), noise_scale = 3.2
# Episode =  702, score =  -3.339 (best =  -1.709), noise_scale = 3.2
# Episode =  703, score =  -5.642 (best =  -1.709), noise_scale = 3.2
# Episode =  704, score =  -2.337 (best =  -1.709), noise_scale = 3.2
# Episode =  705, score =  -3.335 (best =  -1.709), noise_scale = 3.2
# ...
# Episode =  766, score =  -3.030 (best =  -1.701), noise_scale = 3.2
# Episode =  767, score =  -4.816 (best =  -1.701), noise_scale = 3.2
# Episode =  768, score =  -3.074 (best =  -1.701), noise_scale = 3.2
# Episode =  769, score =  -4.122 (best =  -1.701), noise_scale = 3.2
# Episode =  770, score =  -5.129 (best =  -1.701), noise_scale = 3.2
# Episode =  771, score =  -3.909 (best =  -1.701), noise_scale = 3.2
# Episode =  772, score =  -2.507 (best =  -1.701), noise_scale = 3.2
# Episode =  773, score =  -4.303 (best =  -1.701), noise_scale = 3.2
# Episode =  774, score =  -3.586 (best =  -1.701), noise_scale = 3.2
# Episode =  775, score =  -4.034 (best =  -1.701), noise_scale = 3.2
# Episode =  776, score =  -3.784 (best =  -1.701), noise_scale = 3.2
# Episode =  777, score =  -3.220 (best =  -1.701), noise_scale = 3.2
# Episode =  778, score =  -3.164 (best =  -1.701), noise_scale = 3.2
# Episode =  779, score =  -2.836 (best =  -1.701), noise_scale = 3.2
# Episode =  780, score =  -3.686 (best =  -1.701), noise_scale = 3.2
# Episode =  781, score =  -3.032 (best =  -1.701), noise_scale = 3.2
# Episode =  782, score =  -3.284 (best =  -1.701), noise_scale = 3.2
# Episode =  783, score =  -3.499 (best =  -1.701), noise_scale = 3.2
# Episode =  784, score =  -3.091 (best =  -1.701), noise_scale = 3.2
# Episode =  785, score =  -2.476 (best =  -1.701), noise_scale = 3.2
# Episode =  786, score =  -4.080 (best =  -1.701), noise_scale = 3.2
# Episode =  787, score =  -4.165 (best =  -1.701), noise_scale = 3.2
# Episode =  788, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  789, score =  -4.143 (best =  -1.701), noise_scale = 3.2
# Episode =  790, score =  -3.069 (best =  -1.701), noise_scale = 3.2
# Episode =  791, score =  -3.693 (best =  -1.701), noise_scale = 3.2
# Episode =  792, score =  -5.326 (best =  -1.701), noise_scale = 3.2
# Episode =  793, score =  -3.589 (best =  -1.701), noise_scale = 3.2
# Episode =  794, score =  -4.130 (best =  -1.701), noise_scale = 3.2
# Episode =  795, score =  -2.964 (best =  -1.701), noise_scale = 3.2
# Episode =  796, score =  -2.736 (best =  -1.701), noise_scale = 3.2
# Episode =  797, score =  -4.210 (best =  -1.701), noise_scale = 3.2
# Episode =  798, score =  -2.868 (best =  -1.701), noise_scale = 3.2
# Episode =  799, score =  -3.348 (best =  -1.701), noise_scale = 3.2
# Episode =  800, score =  -4.955 (best =  -1.701), noise_scale = 3.2
# Episode =  801, score =  -3.043 (best =  -1.701), noise_scale = 3.2
# Episode =  802, score =  -5.290 (best =  -1.701), noise_scale = 3.2
# Episode =  803, score =  -3.106 (best =  -1.701), noise_scale = 3.2
# Episode =  804, score =  -3.558 (best =  -1.701), noise_scale = 3.2
# Episode =  805, score =  -3.957 (best =  -1.701), noise_scale = 3.2
# Episode =  806, score =  -4.565 (best =  -1.701), noise_scale = 3.2
# Episode =  807, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  808, score =  -3.404 (best =  -1.701), noise_scale = 3.2
# Episode =  809, score =  -3.237 (best =  -1.701), noise_scale = 3.2
# Episode =  810, score =  -2.980 (best =  -1.701), noise_scale = 3.2
# Episode =  811, score =  -3.035 (best =  -1.701), noise_scale = 3.2
# Episode =  812, score =  -3.042 (best =  -1.701), noise_scale = 3.2
# Episode =  813, score =  -2.291 (best =  -1.701), noise_scale = 3.2
# Episode =  814, score =  -4.316 (best =  -1.701), noise_scale = 3.2
# Episode =  815, score =  -3.680 (best =  -1.701), noise_scale = 3.2
# Episode =  816, score =  -2.601 (best =  -1.701), noise_scale = 3.2
# Episode =  817, score =  -3.473 (best =  -1.701), noise_scale = 3.2
# Episode =  818, score =  -3.036 (best =  -1.701), noise_scale = 3.2
# Episode =  819, score =  -2.413 (best =  -1.701), noise_scale = 3.2
# Episode =  820, score =  -2.727 (best =  -1.701), noise_scale = 3.2
# Episode =  821, score =  -3.038 (best =  -1.701), noise_scale = 3.2
# Episode =  822, score =  -4.764 (best =  -1.701), noise_scale = 3.2
# Episode =  823, score =  -6.173 (best =  -1.701), noise_scale = 3.2
# Episode =  824, score =  -2.922 (best =  -1.701), noise_scale = 3.2
# Episode =  825, score =  -3.573 (best =  -1.701), noise_scale = 3.2
# Episode =  826, score =  -2.608 (best =  -1.701), noise_scale = 3.2
# Episode =  827, score =  -3.080 (best =  -1.701), noise_scale = 3.2
# Episode =  828, score =  -3.076 (best =  -1.701), noise_scale = 3.2
# Episode =  829, score =  -3.780 (best =  -1.701), noise_scale = 3.2
# Episode =  830, score =  -4.301 (best =  -1.701), noise_scale = 3.2
# Episode =  831, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  832, score =  -4.247 (best =  -1.701), noise_scale = 3.2
# Episode =  833, score =  -4.547 (best =  -1.701), noise_scale = 3.2
# Episode =  834, score =  -3.263 (best =  -1.701), noise_scale = 3.2
# Episode =  835, score =  -3.031 (best =  -1.701), noise_scale = 3.2
# Episode =  836, score =  -3.042 (best =  -1.701), noise_scale = 3.2
# Episode =  837, score =  -3.297 (best =  -1.701), noise_scale = 3.2
# Episode =  838, score =  -3.622 (best =  -1.701), noise_scale = 3.2
# Episode =  839, score =  -4.815 (best =  -1.701), noise_scale = 3.2
# Episode =  840, score =  -3.164 (best =  -1.701), noise_scale = 3.2
# Episode =  841, score =  -3.080 (best =  -1.701), noise_scale = 3.2
# Episode =  842, score =  -3.329 (best =  -1.701), noise_scale = 3.2
# Episode =  843, score =  -3.045 (best =  -1.701), noise_scale = 3.2
# Episode =  844, score =  -4.176 (best =  -1.701), noise_scale = 3.2
# Episode =  845, score =  -3.852 (best =  -1.701), noise_scale = 3.2
# Episode =  846, score =  -2.304 (best =  -1.701), noise_scale = 3.2
# Episode =  847, score =  -2.281 (best =  -1.701), noise_scale = 3.2
# Episode =  848, score =  -5.338 (best =  -1.701), noise_scale = 3.2
# Episode =  849, score =  -3.982 (best =  -1.701), noise_scale = 3.2
# Episode =  850, score =  -2.721 (best =  -1.701), noise_scale = 3.2
# Episode =  851, score =  -6.138 (best =  -1.701), noise_scale = 3.2
# Episode =  852, score =  -2.457 (best =  -1.701), noise_scale = 3.2
# Episode =  853, score =  -2.187 (best =  -1.701), noise_scale = 3.2
# Episode =  854, score =  -3.197 (best =  -1.701), noise_scale = 3.2
# Episode =  855, score =  -3.168 (best =  -1.701), noise_scale = 3.2
# Episode =  856, score =  -4.554 (best =  -1.701), noise_scale = 3.2
# Episode =  857, score =  -3.058 (best =  -1.701), noise_scale = 3.2
# Episode =  858, score =  -3.843 (best =  -1.701), noise_scale = 3.2
# Episode =  859, score =  -3.061 (best =  -1.701), noise_scale = 3.2
# Episode =  860, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  861, score =  -6.047 (best =  -1.701), noise_scale = 3.2
# Episode =  862, score =  -3.910 (best =  -1.701), noise_scale = 3.2
# Episode =  863, score =  -3.038 (best =  -1.701), noise_scale = 3.2
# Episode =  864, score =  -2.198 (best =  -1.701), noise_scale = 3.2
# Episode =  865, score =  -4.188 (best =  -1.701), noise_scale = 3.2
# Episode =  866, score =  -3.591 (best =  -1.701), noise_scale = 3.2
# Episode =  867, score =  -3.074 (best =  -1.701), noise_scale = 3.2
# Episode =  868, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  869, score =  -2.828 (best =  -1.701), noise_scale = 3.2
# Episode =  870, score =  -3.235 (best =  -1.701), noise_scale = 3.2
# Episode =  871, score =  -3.898 (best =  -1.701), noise_scale = 3.2
# Episode =  872, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  873, score =  -2.819 (best =  -1.701), noise_scale = 3.2
# Episode =  874, score =  -3.325 (best =  -1.701), noise_scale = 3.2
# Episode =  875, score =  -3.097 (best =  -1.701), noise_scale = 3.2
# Episode =  876, score =  -3.967 (best =  -1.701), noise_scale = 3.2
# Episode =  877, score =  -2.727 (best =  -1.701), noise_scale = 3.2
# Episode =  878, score =  -3.453 (best =  -1.701), noise_scale = 3.2
# Episode =  879, score =  -2.157 (best =  -1.701), noise_scale = 3.2
# Episode =  880, score =  -3.481 (best =  -1.701), noise_scale = 3.2
# Episode =  881, score =  -3.700 (best =  -1.701), noise_scale = 3.2
# Episode =  882, score =  -3.038 (best =  -1.701), noise_scale = 3.2
# Episode =  883, score =  -4.297 (best =  -1.701), noise_scale = 3.2
# Episode =  884, score =  -3.701 (best =  -1.701), noise_scale = 3.2
# Episode =  885, score =  -3.116 (best =  -1.701), noise_scale = 3.2
# Episode =  886, score =  -3.029 (best =  -1.701), noise_scale = 3.2
# Episode =  887, score =  -2.591 (best =  -1.701), noise_scale = 3.2
# Episode =  888, score =  -5.092 (best =  -1.701), noise_scale = 3.2
# Episode =  889, score =  -2.245 (best =  -1.701), noise_scale = 3.2
# Episode =  890, score =  -3.650 (best =  -1.701), noise_scale = 3.2
# Episode =  891, score =  -3.404 (best =  -1.701), noise_scale = 3.2
# Episode =  892, score =  -4.323 (best =  -1.701), noise_scale = 3.2
# Episode =  893, score =  -3.037 (best =  -1.701), noise_scale = 3.2
# Episode =  894, score =  -3.354 (best =  -1.701), noise_scale = 3.2
# Episode =  895, score =  -3.513 (best =  -1.701), noise_scale = 3.2
# Episode =  896, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  897, score =  -4.267 (best =  -1.701), noise_scale = 3.2
# Episode =  898, score =  -3.581 (best =  -1.701), noise_scale = 3.2
# Episode =  899, score =  -3.107 (best =  -1.701), noise_scale = 3.2
# Episode =  900, score =  -2.232 (best =  -1.701), noise_scale = 3.2
# Episode =  901, score =  -3.154 (best =  -1.701), noise_scale = 3.2
# Episode =  902, score =  -3.356 (best =  -1.701), noise_scale = 3.2
# Episode =  903, score =  -3.038 (best =  -1.701), noise_scale = 3.2
# Episode =  904, score =  -2.757 (best =  -1.701), noise_scale = 3.2
# Episode =  905, score =  -5.034 (best =  -1.701), noise_scale = 3.2
# Episode =  906, score =  -2.838 (best =  -1.701), noise_scale = 3.2
# Episode =  907, score =  -5.438 (best =  -1.701), noise_scale = 3.2
# Episode =  908, score =  -4.062 (best =  -1.701), noise_scale = 3.2
# Episode =  909, score =  -2.684 (best =  -1.701), noise_scale = 3.2
# Episode =  910, score =  -3.450 (best =  -1.701), noise_scale = 3.2
# Episode =  911, score =  -3.093 (best =  -1.701), noise_scale = 3.2
# Episode =  912, score =  -4.114 (best =  -1.701), noise_scale = 3.2
# Episode =  913, score =  -6.585 (best =  -1.701), noise_scale = 3.2
# Episode =  914, score =  -5.508 (best =  -1.701), noise_scale = 3.2
# Episode =  915, score =  -3.664 (best =  -1.701), noise_scale = 3.2
# Episode =  916, score =  -3.080 (best =  -1.701), noise_scale = 3.2
# Episode =  917, score =  -3.181 (best =  -1.701), noise_scale = 3.2
# Episode =  918, score =  -3.094 (best =  -1.701), noise_scale = 3.2
# Episode =  919, score =  -3.450 (best =  -1.701), noise_scale = 3.2
# Episode =  920, score =  -2.567 (best =  -1.701), noise_scale = 3.2
# Episode =  921, score =  -3.035 (best =  -1.701), noise_scale = 3.2
# Episode =  922, score =  -4.633 (best =  -1.701), noise_scale = 3.2
# Episode =  923, score =  -2.375 (best =  -1.701), noise_scale = 3.2
# Episode =  924, score =  -3.518 (best =  -1.701), noise_scale = 3.2
# Episode =  925, score =  -3.457 (best =  -1.701), noise_scale = 3.2
# Episode =  926, score =  -2.980 (best =  -1.701), noise_scale = 3.2
# Episode =  927, score =  -4.898 (best =  -1.701), noise_scale = 3.2
# Episode =  928, score =  -3.227 (best =  -1.701), noise_scale = 3.2
# Episode =  929, score =  -2.784 (best =  -1.701), noise_scale = 3.2
# Episode =  930, score =  -3.120 (best =  -1.701), noise_scale = 3.2
# Episode =  931, score =  -3.303 (best =  -1.701), noise_scale = 3.2
# Episode =  932, score =  -3.784 (best =  -1.701), noise_scale = 3.2
# Episode =  933, score =  -2.428 (best =  -1.701), noise_scale = 3.2
# Episode =  934, score =  -3.768 (best =  -1.701), noise_scale = 3.2
# Episode =  935, score =  -3.796 (best =  -1.701), noise_scale = 3.2
# Episode =  936, score =  -4.161 (best =  -1.701), noise_scale = 3.2
# Episode =  937, score =  -2.798 (best =  -1.701), noise_scale = 3.2
# Episode =  938, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  939, score =  -3.637 (best =  -1.701), noise_scale = 3.2
# Episode =  940, score =  -3.042 (best =  -1.701), noise_scale = 3.2
# Episode =  941, score =  -2.808 (best =  -1.701), noise_scale = 3.2
# Episode =  942, score =  -3.074 (best =  -1.701), noise_scale = 3.2
# Episode =  943, score =  -3.475 (best =  -1.701), noise_scale = 3.2
# Episode =  944, score =  -4.962 (best =  -1.701), noise_scale = 3.2
# Episode =  945, score =  -3.714 (best =  -1.701), noise_scale = 3.2
# Episode =  946, score =  -4.376 (best =  -1.701), noise_scale = 3.2
# Episode =  947, score =  -3.038 (best =  -1.701), noise_scale = 3.2
# Episode =  948, score =  -3.662 (best =  -1.701), noise_scale = 3.2
# Episode =  949, score =  -3.070 (best =  -1.701), noise_scale = 3.2
# Episode =  950, score =  -2.140 (best =  -1.701), noise_scale = 3.2
# Episode =  951, score =  -3.083 (best =  -1.701), noise_scale = 3.2
# Episode =  952, score =  -3.083 (best =  -1.701), noise_scale = 3.2
# Episode =  953, score =  -4.396 (best =  -1.701), noise_scale = 3.2
# Episode =  954, score =  -3.033 (best =  -1.701), noise_scale = 3.2
# Episode =  955, score =  -3.215 (best =  -1.701), noise_scale = 3.2
# Episode =  956, score =  -3.832 (best =  -1.701), noise_scale = 3.2
# Episode =  957, score =  -3.619 (best =  -1.701), noise_scale = 3.2
# Episode =  958, score =  -3.537 (best =  -1.701), noise_scale = 3.2
# Episode =  959, score =  -3.087 (best =  -1.701), noise_scale = 3.2
# Episode =  960, score =  -2.650 (best =  -1.701), noise_scale = 3.2
# Episode =  961, score =  -4.296 (best =  -1.701), noise_scale = 3.2
# Episode =  962, score =  -2.165 (best =  -1.701), noise_scale = 3.2
# Episode =  963, score =  -3.455 (best =  -1.701), noise_scale = 3.2
# Episode =  964, score =  -2.204 (best =  -1.701), noise_scale = 3.2
# Episode =  965, score =  -3.298 (best =  -1.701), noise_scale = 3.2
# Episode =  966, score =  -3.716 (best =  -1.701), noise_scale = 3.2
# Episode =  967, score =  -2.962 (best =  -1.701), noise_scale = 3.2
# Episode =  968, score =  -3.589 (best =  -1.701), noise_scale = 3.2
# Episode =  969, score =  -3.033 (best =  -1.701), noise_scale = 3.2
# Episode =  970, score =  -2.193 (best =  -1.701), noise_scale = 3.2
# Episode =  971, score =  -3.141 (best =  -1.701), noise_scale = 3.2
# Episode =  972, score =  -3.409 (best =  -1.701), noise_scale = 3.2
# Episode =  973, score =  -3.927 (best =  -1.701), noise_scale = 3.2
# Episode =  974, score =  -3.902 (best =  -1.701), noise_scale = 3.2
# Episode =  975, score =  -2.510 (best =  -1.701), noise_scale = 3.2
# Episode =  976, score =  -3.560 (best =  -1.701), noise_scale = 3.2
# Episode =  977, score =  -3.173 (best =  -1.701), noise_scale = 3.2
# Episode =  978, score =  -3.929 (best =  -1.701), noise_scale = 3.2
# Episode =  979, score =  -3.074 (best =  -1.701), noise_scale = 3.2
# Episode =  980, score =  -5.782 (best =  -1.701), noise_scale = 3.2
# Episode =  981, score =  -2.478 (best =  -1.701), noise_scale = 3.2
# Episode =  982, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  983, score =  -3.295 (best =  -1.701), noise_scale = 3.2
# Episode =  984, score =  -3.428 (best =  -1.701), noise_scale = 3.2
# Episode =  985, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  986, score =  -3.069 (best =  -1.701), noise_scale = 3.2
# Episode =  987, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  988, score =  -4.664 (best =  -1.701), noise_scale = 3.2
# Episode =  989, score =  -3.191 (best =  -1.701), noise_scale = 3.2
# Episode =  990, score =  -4.070 (best =  -1.701), noise_scale = 3.2
# Episode =  991, score =  -3.205 (best =  -1.701), noise_scale = 3.2
# Episode =  992, score =  -2.146 (best =  -1.701), noise_scale = 3.2
# Episode =  993, score =  -3.111 (best =  -1.701), noise_scale = 3.2
# Episode =  994, score =  -3.035 (best =  -1.701), noise_scale = 3.2
# Episode =  995, score =  -2.648 (best =  -1.701), noise_scale = 3.2
# Episode =  996, score =  -3.044 (best =  -1.701), noise_scale = 3.2
# Episode =  997, score =  -3.276 (best =  -1.701), noise_scale = 3.2
# Episode =  998, score =  -3.040 (best =  -1.701), noise_scale = 3.2
# Episode =  999, score =  -2.332 (best =  -1.701), noise_scale = 3.2
# Episode = 1000, score =  -3.069 (best =  -1.701), noise_scale = 3.2

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.

#edited task
from task import Task

num_episodes = 5
target_pos = np.array([0., 0., 0.])
task = Task(target_pos=target_pos)
#import my agent
from agents.agent import Agent 
agent = Agent(task) 
totalScore=float("-inf")
bestScore=float("-inf")
bestScores=[]
scores=[]
#create variables to store results 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action*np.ones(4))
        totalScore+=reward
        scores.append(totalScore)
        bestScore=max(bestScore,totalScore)
        bestScores.append(bestScore)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f})".format(
                i_episode, totalScore, bestScore))  
            break
    sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9764fd9e2912> in <module>()
#       9 #import my agent
#      10 from agents.agent import Agent
# ---> 11 agent = Agent(task)
#      12 totalScore=float("-inf")
#      13 bestScore=float("-inf")
#
# ~/udacity/mlCourse/machine-learning/projects/RL-Quadcopter-2/agents/agent.py in __init__(self, task)
#      15
#      16         # Actor (Policy) Model
# ---> 17         self.actor_local = Actor(self.state_size, self.action_size, self.action_low, self.action_high)
#      18         self.actor_target = Actor(self.state_size, self.action_size, self.action_low, self.action_high)
#      19
#
# ~/udacity/mlCourse/machine-learning/projects/RL-Quadcopter-2/agents/actorModel.py in __init__(self, state_size, action_size, action_low, action_high)
#      23         #TODO Initialize any other variables here
#      24
# ---> 25         self.build_model()
#      26
#      27     def build_model(self):
#
# ~/udacity/mlCourse/machine-learning/projects/RL-Quadcopter-2/agents/actorModel.py in build_model(self)
#      60             inputs=[self.model.input, action_gradients, K.learning_phase()],
#      61                         outputs=[],
# ---> 62             updates=updates_op)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in function(inputs, outputs, updates, **kwargs)
#    3007     return tf_keras_backend.function(inputs, outputs,
#    3008                                      updates=updates,
# -> 3009                                      **kwargs)
#    3010
#    3011
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in function(inputs, outputs, updates, name, **kwargs)
#    3771       raise ValueError('Session keyword arguments are not support during '
#    3772                        'eager execution. You passed: %s' % (kwargs,))
# -> 3773     return EagerExecutionFunction(inputs, outputs, updates=updates, name=name)
#    3774
#    3775   if kwargs:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __init__(self, inputs, outputs, updates, name)
#    3618     if updates and not outputs:
#    3619       # Edge case; never happens in practice
# -> 3620       raise ValueError('Cannot create a Keras backend function with updates'
#    3621                        ' but no outputs during eager execution.')
#    3622     graphs = {
#
# ValueError: Cannot create a Keras backend function with updates but no outputs during eager execution.

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
